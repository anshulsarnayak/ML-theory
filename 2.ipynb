# %% [markdown]
# 1. What is the concept of human learning? Please give two examples.
# :Human Learning is the process of acquiring new understanding, knowledge, behaviors, skills, values, attitudes and preferences. Learning from Pattern of behaviours .e.g, Playing guitar , acting on a stage.
#
# 2. What different forms of human learning are there? Are there any machine learning equivalents?
# :
# Different forms of Human learning are ,
# Learning through association - Classical Conditioning.
# Learning through consequences – Operant Conditioning.
# Learning through observation – Modeling/Observational Learning.
#
# Yes there are some machine learning equivalents,
# Observational learning  is like Searching for a Pattern which is ML .
#
# 3. What is machine learning, and how does it work? What are the key responsibilities of machine learning?
# : Machine learning is a learning where machine learns through some given patterns or feeding data.it works with supervised learning if both Input and Output is given or it goes with Unsupervised learning where it finds pattern itself .
# The key responsibilities are,
# 1.Designing ML systems.
# 2.Researching and implementing ML algorithms and tools.
# 3.Selecting appropriate data sets.
# 4.Picking appropriate data representation methods.
# 5.Identifying differences in data distribution that affects model performance.
# 6.Verifying data quality.
# 7.Training and retraining systems when needed.
#
# 4. Define the terms "penalty" and "reward" in the context of reinforcement learning.
# :A reinforcement learning algorithm, which may also be referred to as an agent, learns by interacting with its environment. The agent receives rewards by performing correctly and penalties for performing incorrectly. The agent learns without intervention from a human by maximizing its reward and minimizing its penalty.
#
# 5. Explain the term "learning as a search"?
# :learning can be viewed as the task of searching through a large space of hypotheses implicitly defined by the hypothesis representation. The goal of this search is to find the hypothesis that best fits the training examples.
#
# 6. What are the various goals of machine learning? What is the relationship between these and human learning?
# : the goal of ML is to understand the data and make accurate predictions . automation, optimization, and augmentation are the Main goals of ML .Human learning would get so easy because of ML .
#
# 7. Illustrate the various elements of machine learning using a real-life illustration.
# :
# Chatbot.
# Virtual Personal Assistants.
# Predictions while Commuting.
# Videos Surveillance.
# Social Media Services.
# Email Spam and Malware Filtering.
#
# 8. Provide an example of the abstraction method.
# :Abstraction “displays” only the relevant attributes of objects and “hides” the unnecessary details. For example,driving a car.
#
# 9. What is the concept of generalization? What function does it play in the machine learning process?
# :Generalization refers to your model's ability to adapt properly to new, previously unseen data, drawn from the same distribution as the one used to create the model.It Determines whether a model is good or not in machine learning process.
#
# 10. What is classification, exactly? What are the main distinctions between classification and regression?
# : Classification in ML is used to classify the things based on data while regression predicts the exact Value and they are continious Values.
#
# 11. What is regression, and how does it work? Give an example of a real-world problem that was solved using regression.
# :Regression models are used to predict a continuous value .With the help regressor models we can predict the value .the example is Predicting House Price .
#
# 12. Describe the clustering mechanism in detail.
# : Clustering algorithm is used to divide the data with certain features.Clustering is the task of dividing the population or data points into a number of groups such that data points in the same groups are more similar to other data points in the same group than those in other groups. In simple words, the aim is to segregate groups with similar traits and assign them into clusters.
#
# 13. Make brief observations on two of the following topics:
# i. Machine learning algorithms are used
# :
# machine learning uses programmed algorithms that receive and analyse input data to predict output values within an acceptable range. As new data is fed to these algorithms, they learn and optimise their operations to improve performance, developing 'intelligence' over time.
#
# ii. Studying under supervision
# :
# Supervised learning is the types of machine learning in which machines are trained using well "labelled" training data, and on basis of that data, machines predict the output. The labelled data means some input data is already tagged with the correct output.
#
# iii. Studying without supervision
# :
# Unsupervised learning is a type of machine learning in which the algorithm is not provided with any pre-assigned labels or scores for the training data. As a result, unsupervised learning algorithms must first self-discover any naturally occurring patterns in that training data set.
#
# iv. Reinforcement learning is a form of learning based on positive reinforcement.
# :
# Reinforcement learning is an area of machine learning concerned with how intelligent agents ought to take actions in an environment in order to maximize the notion of cumulative reward.
